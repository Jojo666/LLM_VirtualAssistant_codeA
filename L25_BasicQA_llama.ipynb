# %%
# !pip install langchain
# !pip install openai
# !pip install tiktoken
# !pip install chromadb
# !pip install pypdf
# !pip install unstructured==0.7.12
# Out:
# Collecting langchain
#   Obtaining dependency information for langchain from https://files.pythonhosted.org/packages/ce/e1/59fc4dbe3a72be422c62ca96e670d590a0f7b6c795fdd0c3d757736a1a19/langchain-0.0.274-py3-none-any.whl.metadata
#   Using cached langchain-0.0.274-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: PyYAML>=5.3 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from langchain) (6.0)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Obtaining dependency information for SQLAlchemy<3,>=1.4 from https://files.pythonhosted.org/packages/91/2b/92aadcea86b9ebd681de0b6b2cbfa75193227e607893cfb5feea0cefc461/SQLAlchemy-2.0.20-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached SQLAlchemy-2.0.20-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.4 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from langchain) (3.8.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from langchain) (4.0.2)
# Collecting dataclasses-json<0.6.0,>=0.5.7 (from langchain)
#   Obtaining dependency information for dataclasses-json<0.6.0,>=0.5.7 from https://files.pythonhosted.org/packages/97/5f/e7cc90f36152810cab08b6c9c1125e8bcb9d76f8b3018d101b5f877b386c/dataclasses_json-0.5.14-py3-none-any.whl.metadata
#   Using cached dataclasses_json-0.5.14-py3-none-any.whl.metadata (22 kB)
# Collecting langsmith<0.1.0,>=0.0.21 (from langchain)
#   Obtaining dependency information for langsmith<0.1.0,>=0.0.21 from https://files.pythonhosted.org/packages/2b/cb/3525fb0d1bf144840c726345a107ad35998565a05e99d4bfec755c71ffd8/langsmith-0.0.27-py3-none-any.whl.metadata
#   Downloading langsmith-0.0.27-py3-none-any.whl.metadata (10 kB)
# Collecting numexpr<3.0.0,>=2.8.4 (from langchain)
#   Obtaining dependency information for numexpr<3.0.0,>=2.8.4 from https://files.pythonhosted.org/packages/60/70/1863613deba8ebfe14158d33d7f8d431e8771492d5c3574b9988f6a8ef8b/numexpr-2.8.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached numexpr-2.8.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy<2,>=1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from langchain) (1.21.6)
# Requirement already satisfied: pydantic<3,>=1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from langchain) (1.10.11)
# Requirement already satisfied: requests<3,>=2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from langchain) (2.31.0)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain)
#   Obtaining dependency information for tenacity<9.0.0,>=8.1.0 from https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl.metadata
#   Using cached tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests<3,>=2->langchain) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2023.7.22)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Using cached greenlet-2.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (610 kB)
# Requirement already satisfied: packaging>=17.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (23.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (1.0.0)
# Using cached langchain-0.0.274-py3-none-any.whl (1.6 MB)
# Using cached dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Downloading langsmith-0.0.27-py3-none-any.whl (34 kB)
# Using cached numexpr-2.8.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (382 kB)
# Using cached SQLAlchemy-2.0.20-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# Using cached tenacity-8.2.3-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity, numexpr, greenlet, SQLAlchemy, langsmith, dataclasses-json, langchain
# Successfully installed SQLAlchemy-2.0.20 dataclasses-json-0.5.14 greenlet-2.0.2 langchain-0.0.274 langsmith-0.0.27 numexpr-2.8.5 tenacity-8.2.3
# Collecting openai
#   Obtaining dependency information for openai from https://files.pythonhosted.org/packages/a0/19/7e39855c63b68ef15b1c2c9e4d941026fb0c94940979e161bb5b470f8455/openai-0.27.9-py3-none-any.whl.metadata
#   Using cached openai-0.27.9-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.20 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from openai) (4.65.0)
# Requirement already satisfied: aiohttp in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from openai) (3.8.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests>=2.20->openai) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests>=2.20->openai) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp->openai) (1.3.1)
# Using cached openai-0.27.9-py3-none-any.whl (75 kB)
# Installing collected packages: openai
# Successfully installed openai-0.27.9
# Collecting tiktoken
#   Using cached tiktoken-0.4.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
# Collecting regex>=2022.1.18 (from tiktoken)
#   Obtaining dependency information for regex>=2022.1.18 from https://files.pythonhosted.org/packages/c0/f4/278e305e02245937579a7952b8a3205116b4d2480a3c03fa11e599b773d6/regex-2023.8.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached regex-2023.8.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: requests>=2.26.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (2023.7.22)
# Using cached regex-2023.8.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (771 kB)
# Installing collected packages: regex, tiktoken
# Successfully installed regex-2023.8.8 tiktoken-0.4.0
# Collecting chromadb
#   Obtaining dependency information for chromadb from https://files.pythonhosted.org/packages/bd/47/17b44d8c372d32ec8cf1901801e163e960859b9e610cc623a3350afe8924/chromadb-0.4.7-py3-none-any.whl.metadata
#   Using cached chromadb-0.4.7-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: requests>=2.28 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic<2.0,>=1.9 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from chromadb) (1.10.11)
# Collecting chroma-hnswlib==0.7.2 (from chromadb)
#   Using cached chroma_hnswlib-0.7.2-cp39-cp39-linux_x86_64.whl
# Collecting fastapi<0.100.0,>=0.95.2 (from chromadb)
#   Obtaining dependency information for fastapi<0.100.0,>=0.95.2 from https://files.pythonhosted.org/packages/73/eb/03b691afa0b5ffa1e93ed34f97ec1e7855c758efbdcfb16c209af0b0506b/fastapi-0.99.1-py3-none-any.whl.metadata
#   Using cached fastapi-0.99.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvicorn[standard]>=0.18.3 (from chromadb)
#   Obtaining dependency information for uvicorn[standard]>=0.18.3 from https://files.pythonhosted.org/packages/79/96/b0882a1c3f7ef3dd86879e041212ae5b62b4bd352320889231cc735a8e8f/uvicorn-0.23.2-py3-none-any.whl.metadata
#   Using cached uvicorn-0.23.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy>=1.21.6 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from chromadb) (1.21.6)
# Collecting posthog>=2.4.0 (from chromadb)
#   Obtaining dependency information for posthog>=2.4.0 from https://files.pythonhosted.org/packages/a7/73/35758818228c70348be4c3c66a76653c62e894e0e3c3461453c5341ca926/posthog-3.0.2-py2.py3-none-any.whl.metadata
#   Using cached posthog-3.0.2-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from chromadb) (4.7.1)
# Collecting pulsar-client>=3.1.0 (from chromadb)
#   Obtaining dependency information for pulsar-client>=3.1.0 from https://files.pythonhosted.org/packages/f1/c2/e71786bd365a4ad33993aa7aa80e6e4c0e586bb0286bb92e5aeedd9a7a90/pulsar_client-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached pulsar_client-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.0 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Obtaining dependency information for onnxruntime>=1.14.1 from https://files.pythonhosted.org/packages/50/d5/f156d808c9cc59e7a8b87843a5313719d01eec7d3b17ca3f6b6f0fbee0f0/onnxruntime-1.15.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached onnxruntime-1.15.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Using cached tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from chromadb) (4.65.0)
# Collecting overrides>=7.3.1 (from chromadb)
#   Obtaining dependency information for overrides>=7.3.1 from https://files.pythonhosted.org/packages/da/28/3fa6ef8297302fc7b3844980b6c5dbc71cdbd4b61e9b2591234214d5ab39/overrides-7.4.0-py3-none-any.whl.metadata
#   Using cached overrides-7.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: importlib-resources in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from chromadb) (6.0.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (593 kB)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi<0.100.0,>=0.95.2->chromadb)
#   Obtaining dependency information for starlette<0.28.0,>=0.27.0 from https://files.pythonhosted.org/packages/58/f8/e2cca22387965584a409795913b774235752be4176d276714e15e1a58884/starlette-0.27.0-py3-none-any.whl.metadata
#   Using cached starlette-0.27.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Obtaining dependency information for flatbuffers from https://files.pythonhosted.org/packages/6f/12/d5c79ee252793ffe845d58a913197bfa02ae9a0b5c9bc3dc4b58d477b9e7/flatbuffers-23.5.26-py2.py3-none-any.whl.metadata
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Requirement already satisfied: packaging in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (23.1)
# Requirement already satisfied: protobuf in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Collecting sympy (from onnxruntime>=1.14.1->chromadb)
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Requirement already satisfied: six>=1.5 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.16.0)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: python-dateutil>2.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (2.8.2)
# Requirement already satisfied: certifi in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pulsar-client>=3.1.0->chromadb) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests>=2.28->chromadb) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests>=2.28->chromadb) (1.26.15)
# Requirement already satisfied: click>=7.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (8.0.4)
# Collecting h11>=0.8 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Obtaining dependency information for httptools>=0.5.0 from https://files.pythonhosted.org/packages/28/7c/5ddc99737fb141bd9077f45af23e9d3c83496b4c04bf463e4e72f57043cd/httptools-0.6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached httptools-0.6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pyyaml>=5.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (6.0)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvloop-0.17.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Obtaining dependency information for watchfiles>=0.13 from https://files.pythonhosted.org/packages/e1/46/c9d5ee4871b187d291d62e61c41f9a4d67d4866a89704b0ad16b6949e9bd/watchfiles-0.20.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached watchfiles-0.20.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached websockets-11.0.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
# Requirement already satisfied: zipp>=3.1.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from importlib-resources->chromadb) (3.16.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (3.7.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting mpmath>=0.19 (from sympy->onnxruntime>=1.14.1->chromadb)
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Requirement already satisfied: sniffio>=1.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (1.1.2)
# Using cached chromadb-0.4.7-py3-none-any.whl (415 kB)
# Using cached fastapi-0.99.1-py3-none-any.whl (58 kB)
# Using cached onnxruntime-1.15.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
# Using cached overrides-7.4.0-py3-none-any.whl (17 kB)
# Using cached posthog-3.0.2-py2.py3-none-any.whl (37 kB)
# Using cached pulsar_client-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
# Using cached httptools-0.6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (432 kB)
# Using cached starlette-0.27.0-py3-none-any.whl (66 kB)
# Using cached watchfiles-0.20.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Using cached uvicorn-0.23.2-py3-none-any.whl (59 kB)
# Installing collected packages: tokenizers, pypika, mpmath, monotonic, flatbuffers, websockets, uvloop, sympy, python-dotenv, pulsar-client, overrides, humanfriendly, httptools, h11, chroma-hnswlib, bcrypt, backoff, watchfiles, uvicorn, starlette, posthog, coloredlogs, onnxruntime, fastapi, chromadb
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.2
#     Uninstalling bcrypt-3.2.2:
#       Successfully uninstalled bcrypt-3.2.2
# Successfully installed backoff-2.2.1 bcrypt-4.0.1 chroma-hnswlib-0.7.2 chromadb-0.4.7 coloredlogs-15.0.1 fastapi-0.99.1 flatbuffers-23.5.26 h11-0.14.0 httptools-0.6.0 humanfriendly-10.0 monotonic-1.6 mpmath-1.3.0 onnxruntime-1.15.1 overrides-7.4.0 posthog-3.0.2 pulsar-client-3.2.0 pypika-0.48.9 python-dotenv-1.0.0 starlette-0.27.0 sympy-1.12 tokenizers-0.13.3 uvicorn-0.23.2 uvloop-0.17.0 watchfiles-0.20.0 websockets-11.0.3
# Collecting pypdf
#   Obtaining dependency information for pypdf from https://files.pythonhosted.org/packages/61/05/e57748dfb0e4592c4261402d6bf1e1ec80249540223112e7c776a329ae17/pypdf-3.15.4-py3-none-any.whl.metadata
#   Using cached pypdf-3.15.4-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing_extensions>=3.7.4.3 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pypdf) (4.7.1)
# Using cached pypdf-3.15.4-py3-none-any.whl (272 kB)
# Installing collected packages: pypdf
# Successfully installed pypdf-3.15.4
# Collecting unstructured==0.7.12
#   Obtaining dependency information for unstructured==0.7.12 from https://files.pythonhosted.org/packages/a4/91/80564119abc4339a775c6f9c3f2085e69d98a1122c8670d8ba562b5fe1d2/unstructured-0.7.12-py3-none-any.whl.metadata
#   Using cached unstructured-0.7.12-py3-none-any.whl.metadata (18 kB)
# Collecting argilla (from unstructured==0.7.12)
#   Obtaining dependency information for argilla from https://files.pythonhosted.org/packages/d2/ff/295f84c389637e1b32800611ae3fbd45bd6c8e5e6e595dfaae1b171ae7d0/argilla-1.14.1-py3-none-any.whl.metadata
#   Using cached argilla-1.14.1-py3-none-any.whl.metadata (14 kB)
# Collecting chardet (from unstructured==0.7.12)
#   Obtaining dependency information for chardet from https://files.pythonhosted.org/packages/38/6f/f5fbc992a329ee4e0f288c1fe0e2ad9485ed064cac731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting filetype (from unstructured==0.7.12)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Collecting lxml (from unstructured==0.7.12)
#   Obtaining dependency information for lxml from https://files.pythonhosted.org/packages/c5/a2/7876f76606725340c989b1c73b5501fc41fb21e50a8597c9ecdb63a05b27/lxml-4.9.3-cp39-cp39-manylinux_2_28_x86_64.whl.metadata
#   Using cached lxml-4.9.3-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting msg-parser (from unstructured==0.7.12)
#   Using cached msg_parser-1.2.0-py2.py3-none-any.whl (101 kB)
# Collecting nltk (from unstructured==0.7.12)
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Collecting openpyxl (from unstructured==0.7.12)
#   Using cached openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Requirement already satisfied: pandas in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from unstructured==0.7.12) (1.4.2)
# Collecting pdf2image (from unstructured==0.7.12)
#   Using cached pdf2image-1.16.3-py3-none-any.whl (11 kB)
# Collecting pdfminer.six (from unstructured==0.7.12)
#   Using cached pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
# Requirement already satisfied: pillow in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from unstructured==0.7.12) (9.1.1)
# Collecting pypandoc (from unstructured==0.7.12)
#   Using cached pypandoc-1.11-py3-none-any.whl (20 kB)
# Collecting python-docx (from unstructured==0.7.12)
#   Using cached python_docx-0.8.11-py3-none-any.whl
# Collecting python-pptx (from unstructured==0.7.12)
#   Using cached python_pptx-0.6.21-py3-none-any.whl
# Collecting python-magic (from unstructured==0.7.12)
#   Using cached python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: markdown in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from unstructured==0.7.12) (3.4.4)
# Requirement already satisfied: requests in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from unstructured==0.7.12) (2.31.0)
# Requirement already satisfied: tabulate in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from unstructured==0.7.12) (0.9.0)
# Collecting xlrd (from unstructured==0.7.12)
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Collecting httpx<0.24,>=0.15 (from argilla->unstructured==0.7.12)
#   Using cached httpx-0.23.3-py3-none-any.whl (71 kB)
# Collecting deprecated~=1.2.0 (from argilla->unstructured==0.7.12)
#   Obtaining dependency information for deprecated~=1.2.0 from https://files.pythonhosted.org/packages/20/8d/778b7d51b981a96554f29136cd59ca7880bf58094338085bcf2a979a0e6a/Deprecated-1.2.14-py2.py3-none-any.whl.metadata
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from argilla->unstructured==0.7.12) (23.1)
# Requirement already satisfied: pydantic<2.0,>=1.10.7 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from argilla->unstructured==0.7.12) (1.10.11)
# Collecting wrapt<1.15,>=1.13 (from argilla->unstructured==0.7.12)
#   Using cached wrapt-1.14.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
# Requirement already satisfied: numpy<1.24.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from argilla->unstructured==0.7.12) (1.21.6)
# Requirement already satisfied: tqdm>=4.27.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from argilla->unstructured==0.7.12) (4.65.0)
# Requirement already satisfied: backoff in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from argilla->unstructured==0.7.12) (2.2.1)
# Requirement already satisfied: monotonic in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from argilla->unstructured==0.7.12) (1.6)
# Requirement already satisfied: rich!=13.1.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from argilla->unstructured==0.7.12) (13.4.2)
# Collecting typer<0.8.0,>=0.6.0 (from argilla->unstructured==0.7.12)
#   Using cached typer-0.7.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pandas->unstructured==0.7.12) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pandas->unstructured==0.7.12) (2023.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from markdown->unstructured==0.7.12) (6.8.0)
# Collecting olefile>=0.46 (from msg-parser->unstructured==0.7.12)
#   Using cached olefile-0.46-py2.py3-none-any.whl
# Requirement already satisfied: click in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from nltk->unstructured==0.7.12) (8.0.4)
# Requirement already satisfied: joblib in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from nltk->unstructured==0.7.12) (1.3.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from nltk->unstructured==0.7.12) (2023.8.8)
# Collecting et-xmlfile (from openpyxl->unstructured==0.7.12)
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pdfminer.six->unstructured==0.7.12) (2.0.12)
# Requirement already satisfied: cryptography>=36.0.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pdfminer.six->unstructured==0.7.12) (36.0.2)
# Collecting XlsxWriter>=0.5.7 (from python-pptx->unstructured==0.7.12)
#   Obtaining dependency information for XlsxWriter>=0.5.7 from https://files.pythonhosted.org/packages/37/94/25d3ec8587974de7ebd790232aa3155abfe44ed23df7ccaa4645977a1cbe/XlsxWriter-3.1.2-py3-none-any.whl.metadata
#   Using cached XlsxWriter-3.1.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: idna<4,>=2.5 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests->unstructured==0.7.12) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests->unstructured==0.7.12) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests->unstructured==0.7.12) (2023.7.22)
# Requirement already satisfied: cffi>=1.12 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured==0.7.12) (1.15.1)
# Collecting httpcore<0.17.0,>=0.15.0 (from httpx<0.24,>=0.15->argilla->unstructured==0.7.12)
#   Using cached httpcore-0.16.3-py3-none-any.whl (69 kB)
# Collecting rfc3986[idna2008]<2,>=1.3 (from httpx<0.24,>=0.15->argilla->unstructured==0.7.12)
#   Using cached rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: sniffio in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from httpx<0.24,>=0.15->argilla->unstructured==0.7.12) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown->unstructured==0.7.12) (3.16.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pydantic<2.0,>=1.10.7->argilla->unstructured==0.7.12) (4.7.1)
# Requirement already satisfied: six>=1.5 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->unstructured==0.7.12) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from rich!=13.1.0->argilla->unstructured==0.7.12) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from rich!=13.1.0->argilla->unstructured==0.7.12) (2.15.1)
# Requirement already satisfied: pycparser in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured==0.7.12) (2.21)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from httpcore<0.17.0,>=0.15.0->httpx<0.24,>=0.15->argilla->unstructured==0.7.12) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from httpcore<0.17.0,>=0.15.0->httpx<0.24,>=0.15->argilla->unstructured==0.7.12) (3.7.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich!=13.1.0->argilla->unstructured==0.7.12) (0.1.0)
# Requirement already satisfied: exceptiongroup in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from anyio<5.0,>=3.0->httpcore<0.17.0,>=0.15.0->httpx<0.24,>=0.15->argilla->unstructured==0.7.12) (1.1.2)
# Using cached unstructured-0.7.12-py3-none-any.whl (1.4 MB)
# Using cached argilla-1.14.1-py3-none-any.whl (2.5 MB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Using cached lxml-4.9.3-cp39-cp39-manylinux_2_28_x86_64.whl (8.0 MB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached XlsxWriter-3.1.2-py3-none-any.whl (153 kB)
# Installing collected packages: rfc3986, filetype, XlsxWriter, xlrd, wrapt, typer, python-magic, pypandoc, pdf2image, olefile, nltk, lxml, et-xmlfile, chardet, python-pptx, python-docx, openpyxl, msg-parser, httpcore, deprecated, pdfminer.six, httpx, argilla, unstructured
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.15.0
#     Uninstalling wrapt-1.15.0:
#       Successfully uninstalled wrapt-1.15.0
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.0
#     Uninstalling typer-0.9.0:
#       Successfully uninstalled typer-0.9.0
# Successfully installed XlsxWriter-3.1.2 argilla-1.14.1 chardet-5.2.0 deprecated-1.2.14 et-xmlfile-1.1.0 filetype-1.2.0 httpcore-0.16.3 httpx-0.23.3 lxml-4.9.3 msg-parser-1.2.0 nltk-3.8.1 olefile-0.46 openpyxl-3.1.2 pdf2image-1.16.3 pdfminer.six-20221105 pypandoc-1.11 python-docx-0.8.11 python-magic-0.4.27 python-pptx-0.6.21 rfc3986-1.5.0 typer-0.7.0 unstructured-0.7.12 wrapt-1.14.1 xlrd-2.0.1

# %%
# !pip install llama-index
# Out:
# Collecting llama-index
#   Obtaining dependency information for llama-index from https://files.pythonhosted.org/packages/f3/a0/b23f1a4b14cc4905fe39f349be150830a11dc813d34c9ba17bdd7e4961bb/llama_index-0.8.11.post3-py3-none-any.whl.metadata
#   Downloading llama_index-0.8.11.post3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: tiktoken in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: dataclasses-json in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from llama-index) (0.5.14)
# Requirement already satisfied: langchain>=0.0.262 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from llama-index) (0.0.274)
# Requirement already satisfied: sqlalchemy>=2.0.15 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from llama-index) (2.0.20)
# Requirement already satisfied: numpy in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from llama-index) (1.21.6)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from llama-index) (8.2.3)
# Requirement already satisfied: openai>=0.26.4 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from llama-index) (0.27.9)
# Requirement already satisfied: pandas in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from llama-index) (1.4.2)
# Requirement already satisfied: urllib3<2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from llama-index) (1.26.15)
# Collecting fsspec>=2023.5.0 (from llama-index)
#   Obtaining dependency information for fsspec>=2023.5.0 from https://files.pythonhosted.org/packages/e3/bd/4c0a4619494188a9db5d77e2100ab7d544a42e76b2447869d8e124e981d8/fsspec-2023.6.0-py3-none-any.whl.metadata
#   Downloading fsspec-2023.6.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from llama-index) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from llama-index) (4.7.1)
# Requirement already satisfied: beautifulsoup4 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from llama-index) (4.12.2)
# Requirement already satisfied: nest-asyncio in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from llama-index) (1.5.6)
# Requirement already satisfied: PyYAML>=5.3 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from langchain>=0.0.262->llama-index) (6.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from langchain>=0.0.262->llama-index) (3.8.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from langchain>=0.0.262->llama-index) (4.0.2)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.21 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from langchain>=0.0.262->llama-index) (0.0.27)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from langchain>=0.0.262->llama-index) (2.8.5)
# Requirement already satisfied: pydantic<3,>=1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from langchain>=0.0.262->llama-index) (1.10.11)
# Requirement already satisfied: requests<3,>=2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from langchain>=0.0.262->llama-index) (2.31.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from dataclasses-json->llama-index) (3.20.1)
# Requirement already satisfied: tqdm in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from openai>=0.26.4->llama-index) (4.65.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from sqlalchemy>=2.0.15->llama-index) (2.0.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index) (1.0.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from beautifulsoup4->llama-index) (2.3.2.post1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pandas->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from pandas->llama-index) (2023.3)
# Requirement already satisfied: regex>=2022.1.18 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from tiktoken->llama-index) (2023.8.8)
# Requirement already satisfied: attrs>=17.3.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.262->llama-index) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.262->llama-index) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.262->llama-index) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.262->llama-index) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.262->llama-index) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.262->llama-index) (1.3.1)
# Requirement already satisfied: packaging>=17.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index) (23.1)
# Requirement already satisfied: six>=1.5 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->llama-index) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests<3,>=2->langchain>=0.0.262->llama-index) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from requests<3,>=2->langchain>=0.0.262->llama-index) (2023.7.22)
# Downloading llama_index-0.8.11.post3-py3-none-any.whl (711 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 711.2/711.2 kB 36.8 MB/s eta 0:00:00
# Downloading fsspec-2023.6.0-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 34.6 MB/s eta 0:00:00
# Installing collected packages: fsspec, llama-index
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.3.0
#     Uninstalling fsspec-2022.3.0:
#       Successfully uninstalled fsspec-2022.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# s3fs 2022.3.0 requires fsspec==2022.3.0, but you have fsspec 2023.6.0 which is incompatible.
# Successfully installed fsspec-2023.6.0 llama-index-0.8.11.post3

# %%
import os

os.environ['OPENAI_API_KEY'] = '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'

# %%
pdf_folder_path = '/home/jovyan/workspace/MangrovePDFs'

# %%
from pathlib import Path
from llama_index import download_loader

PDFReader = download_loader("PDFReader")

from llama_index import SimpleDirectoryReader

documents = SimpleDirectoryReader(pdf_folder_path).load_data()

#vector index designed to work with text embeddings generated by the GPT (Generative Pre-trained Transformer) language models, 
#which are part of the Transformer architecture

from llama_index import GPTVectorStoreIndex

index = GPTVectorStoreIndex.from_documents(documents)

# %%
#create a query engine from a previously built index.
#A query engine is a component that allows you to perform efficient similarity searches or queries on the indexed data using vectors or embeddings.


query_engine = index.as_query_engine()

# %%
response = query_engine.query("What is blue carbon")
print(response.response)
# Out:
# Blue carbon refers to the carbon that is stored in coastal ecosystems such as mangroves and seagrasses. These ecosystems have the ability to sequester and store large amounts of carbon in their soil. Blue carbon is considered important in the fight against climate change as it helps to mitigate the effects of greenhouse gas emissions by removing carbon dioxide from the atmosphere and storing it in the soil.

# %%
response = query_engine.query("What ecosystem services can mangroves provide?")
print(response.response)
# Out:
# Mangroves can provide a multitude of ecosystem services, including Ecosystem-based Disaster Risk Reduction (Eco-DRR), acting as breeding grounds for marine fauna, serving as a pollutant sink, offering economic services through forest products, contributing to soil consolidation, and enhancing resilience.
